# %% [markdown]
# <a href="https://colab.research.google.com/github/freekani/ChallengeTeamA/blob/ToSonicPi_GetTempo/SonicPi_Test/XML2CSV/MusicXML2CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# change.xmlからresult.csvに変更
#
# ### 変更結果：
#
# |Step|Pitch|長さ|小節|
# |----|----|----|----|
# |1|4|1|1|
# |1|4|1|1|
# |2|4|1|1|
# |2|4|1|1|
# |3|4|1|1|
# |3|4|1|1|
# |4|4|1|1|
# |4|4|1|1|
# |1|3|2|1|
# |7|2|2|1|
# |1|3|2|1|
# |2|3|2|1|

# %%
# モジュールのインポート
import xml.etree.ElementTree as ET
import csv

arr = []

# xmlファイルの読み込み
tree = ET.parse('/content/change.xml')

# XMLを取得
root = tree.getroot()

# 配列用意
# 和音はフォーマットしてから入れたい

measures = [{  # 曲データ配列
    'notes': [{  # ノーツ配列
        'type': '単音',  # ノーツタイプ(単音、和音、休符)
        'duration': 1,  # 長さ
        'pitch': [{  # 音程情報配列、和音の場合のみ複数入る、休符は空
            'step': 'C',
            'octave': 4,
        }]
    }]
}]

notes = []
# notes = [{  # ノーツ配列
#     'measure' : 1,
#     'type': '単音',  # ノーツタイプ(単音、和音、休符)
#     'duration': 1,  # 長さ
#     'pitch': [{  # 音程情報配列、和音の場合のみ複数入る、休符は空
#         'step': 'C',
#         'octave': 4,
#     }]
# }]

for part_index, part in enumerate(root.iter('part')):
  for index_measure, measure in enumerate(part.iter('measure')):
    print('小節:' + str(measure.attrib['number']))
    sum = 0
    for index_note, note in enumerate(measure.iter('note')):
      print('　ノート:')
      print('　　duration:' + note.findtext('duration'))
      if note.findall('rest'):
        print("　　分類:休符")
        notes.append(dict([
          ("measure",measure.attrib['number']),
          ("type", "休符"),
          ("duration", str(note.findtext('duration'))),
          ("pitch", dict([('step', 0),
            ('octave', 0)
          ]))
        ]))
      elif note.findall('chord'):
        for pitch in note.iter('pitch'):
          print('　　pitch:(step:' + pitch.findtext('step') + ', octave:' + pitch.findtext('octave') + ")")
          notes.append(dict([
            ("measure",measure.attrib['number']),
            ("type", "和音"),
            ("duration", str(note.findtext('duration'))),
            ("pitch", dict([('step', pitch.findtext('step')),
              ('octave', pitch.findtext('octave'))
            ]))
          ]))
      else: 
        for pitch in note.iter('pitch'):
          print('　　pitch:(step:' + pitch.findtext('step') + ', octave:' + pitch.findtext('octave') + ")")
          notes.append(dict([
            ("measure",measure.attrib['number']),
            ("type", "単音"),
            ("duration", str(note.findtext('duration'))),
            ("pitch", dict([('step', pitch.findtext('step')),
              ('octave', pitch.findtext('octave'))
            ])
          )]))
          print("　　分類:単音")
          print('　　type:' + note.findtext('type'))
          sum += int(note.findtext('duration'))
    print("                 合計:" + str(sum))

# note内はchord/とrest/が入る時は場合分けする
# chord:和音
# rest:休符
# chordタグ直前の音も含む（default-xの値が一致した場合は和音）
# ＝＞連続かつx軸が同値なノーツ群を和音とする

# 和音によって合計値が増える

# duration/小節の合計値を一音の長さとすることで曲ごとに基準の違うdurationを均一化

# halfとか16thが二分音符とか十六分音符を表してそうだけど休符にないので無視

# 番号遡るの面倒だしx軸保存した配列作ったほうが早い

# 次の拍までは全拍の速度で再生＝＞デトロイトのピアノみたいなやつ

csvData = []


def format_chord(str):#どこに合わせるか知らんから数字と英語の対応は適当
    val = ""
    if str == "A":
        val = 6
    elif str == "B":
        val = 7
    elif str == "C":
        val = 1
    elif str == "D":
        val = 2
    elif str == "E":
        val = 3
    elif str == "F":
        val = 4
    elif str == "G":
        val = 5
    elif str == 0:
        val = 0
    return val


for note in notes:
    csvData.append([
        format_chord(note['pitch']['step']),
        note['pitch']['octave'],
        note['duration'],
        note['measure']
    ])

with open('./result.csv', 'w',newline="") as f:
    writer = csv.writer(f)
    writer.writerows(csvData)


# print(csvData)
# Out:
# 小節:1
# 　ノート:
# 　　duration:1
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:D, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:D, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:F, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:F, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:B, octave:2)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:D, octave:3)
# 　　分類:単音
# 　　type:quarter
#                  合計:16
# 小節:2
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:D, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　分類:休符
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:2)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:3)
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　ノート:
# 　　duration:2
# 　　分類:休符
#                  合計:12
# 小節:3
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:D, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:F, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:2)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　　分類:単音
# 　　type:quarter
#                  合計:16
# 小節:4
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:D, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　分類:休符
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:2)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　　分類:単音
# 　　type:quarter
#                  合計:14
# 小節:5
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:F, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:A, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:F, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:F, octave:3)
# 　　分類:単音
# 　　type:quarter
#                  合計:16
# 小節:6
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:F, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　分類:休符
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:2)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　　分類:単音
# 　　type:quarter
#                  合計:14
# 小節:7
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　分類:休符
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　分類:休符
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
#                  合計:12
# 小節:8
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　分類:休符
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　分類:休符
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
#                  合計:12
# 小節:9
# 　ノート:
# 　　duration:1
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:D, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:D, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:F, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:1
# 　　pitch:(step:F, octave:4)
# 　　分類:単音
# 　　type:eighth
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:B, octave:2)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:F, octave:3)
# 　　分類:単音
# 　　type:quarter
#                  合計:16
# 小節:10
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:D, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:4)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　分類:休符
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:2)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:C, octave:3)
# 　　分類:単音
# 　　type:quarter
# 　ノート:
# 　　duration:2
# 　　pitch:(step:E, octave:3)
# 　ノート:
# 　　duration:2
# 　　pitch:(step:G, octave:3)
# 　ノート:
# 　　duration:2
# 　　分類:休符
#                  合計:12

# %%
notes
# Out:
# [{'default-x': 0,
#   'duration': '1',
#   'measure': '1',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '1',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '1',
#   'pitch': {'octave': '4', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '1',
#   'pitch': {'octave': '4', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '1',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '1',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '1',
#   'pitch': {'octave': '4', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '1',
#   'pitch': {'octave': '4', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '1',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '1',
#   'pitch': {'octave': '2', 'step': 'B'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '1',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '1',
#   'pitch': {'octave': '3', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': '4', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': '2', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': '-120.00:68.99',
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': '3', 'step': 'E'},
#   'type': '和音'},
#  {'default-x': '-110.00:68.99',
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '和音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '2',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '3',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '3',
#   'pitch': {'octave': '4', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '3',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '3',
#   'pitch': {'octave': '4', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '3',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '3',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '3',
#   'pitch': {'octave': '2', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '3',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '4',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '4',
#   'pitch': {'octave': '4', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '4',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '4',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '4',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '4',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '4',
#   'pitch': {'octave': '2', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '4',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '5',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '5',
#   'pitch': {'octave': '4', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '5',
#   'pitch': {'octave': '4', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '5',
#   'pitch': {'octave': '4', 'step': 'A'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '5',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '5',
#   'pitch': {'octave': '3', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '5',
#   'pitch': {'octave': '3', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '5',
#   'pitch': {'octave': '3', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '6',
#   'pitch': {'octave': '4', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '6',
#   'pitch': {'octave': '4', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '6',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '6',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '6',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '6',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '6',
#   'pitch': {'octave': '2', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '6',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': '3', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': '-110.00:41.59',
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '和音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': '3', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': '-110.00:100.76',
#   'duration': '2',
#   'measure': '7',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '和音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': '3', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': '-110.00:124.13',
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '和音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': '3', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': '-110.00:269.88',
#   'duration': '2',
#   'measure': '8',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '和音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '9',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '9',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '9',
#   'pitch': {'octave': '4', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '9',
#   'pitch': {'octave': '4', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '9',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '9',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '9',
#   'pitch': {'octave': '4', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '1',
#   'measure': '9',
#   'pitch': {'octave': '4', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '9',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '9',
#   'pitch': {'octave': '2', 'step': 'B'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '9',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '9',
#   'pitch': {'octave': '3', 'step': 'F'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': '4', 'step': 'E'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': '4', 'step': 'D'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': '4', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': '2', 'step': 'G'},
#   'type': '単音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': '3', 'step': 'C'},
#   'type': '単音'},
#  {'default-x': '-120.00:160.56',
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': '3', 'step': 'E'},
#   'type': '和音'},
#  {'default-x': '-110.00:160.56',
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': '3', 'step': 'G'},
#   'type': '和音'},
#  {'default-x': 0,
#   'duration': '2',
#   'measure': '10',
#   'pitch': {'octave': 0, 'step': 0},
#   'type': '休符'}]
